# %% [markdown]
# # Day 7

# %%
import plotly.express as px

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# ### Reading the Avengers Data

# %% [markdown]
# ### Plotting the Popularity

# %% [markdown]
# ## Line Graphs

# %% [markdown]
# ## Animation Plots

# %% [markdown]
# ### Reading World Data

# %% [markdown]
# ### Plotting World Data
